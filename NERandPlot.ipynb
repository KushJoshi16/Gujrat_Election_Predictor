# %%
import pandas as pd
import os 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# os.chdir(r'C:\Users\Harshit\Gujarat_Elec\Data')
df=pd.read_csv("Tweets1.csv")

# %%
df
# Out:
#       Tweet Scraped         Username  \
# 0                 1   hatefreeworldX
# 1                 2  sashastrakranti
# 2                 3     GuptaPragnya
# 3                 5     CongressFans
# 4                 7  Har_preet_Kaur_
# ...             ...              ...
# 2118             41      iamShamanth
# 2119             42       anoop_xing
# 2120            203  Harjind35133736
# 2121            207   kurtapajama101
# 2122              1      tv9gujarati
#
#                                             Description          Location  \
# 0     Vasudhaiva Kutumbakam-World is family | Bharat...     🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵
# 1                                                सनातनी               NaN
# 2     Constitution of India above all. My opinions a...             India
# 3                                                   NaN               NaN
# 4     Assistant Professor of English | UGC NET Quali...               NaN
# ...

# %%
df=df.drop(['Tweet Scraped','Username','Hashtags Used','Description'],axis=1)

# %%
df
# Out:
#               Location  Followinf Count  Followers Count  Total Tweets  \
# 0        🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵              2019            13689        347524
# 1                  NaN              448               90          2838
# 2                India             1784            10797         89266
# 3                  NaN             5081            19230        440481
# 4                  NaN              322              289         12116
# ...                ...              ...              ...           ...
# 2118  Bengaluru, India               82              244         14467
# 2119         Bangalore              920              358          7769
# 2120               NaN             3613             2443        138018
# 2121               NaN                6                5           800
# 2122    Gujarat, India               63           887426        416251
#
#       Retweet Count                                         Tweet Text
# ...

# %%
df['Location'].value_counts()
# Out:
# India                        247
# New Delhi, India              81
# Mumbai, India                 52
# Gujarat, India                45
# New Delhi                     39
#                             ...
# Jetpur Navagadh, India         1
# jambughoda                     1
# Ahmedabad                      1
# अखंड भारत                      1
# Where ever work takes me       1
# Name: Location, Length: 500, dtype: int64

# %%
pro=df
value_counts=pro['Location'].value_counts()
to_remove=value_counts[value_counts<=5].index
pro=pro[pro.Location.isin(to_remove)]
pro.head()
# Out:
#                      Location  Followinf Count  Followers Count  Total Tweets  \
# 0               🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵              2019            13689        347524
# 5               Pune & Kuwait             2474              550         37595
# 6         Navi Mumbai, Airoli               83               60         10751
# 10  गोवा (Goa), भारत (Bharat)              424               43         41452
# 12                    N.Delhi             2032             2914         93993
#
#     Retweet Count                                         Tweet Text
# 0              72  An emotional appeal from a Gujarati Mata Ji to...
# 5              16  Finally!! Chappal ki maala for #BJP #Gujarat c...
# 6               5  Honoured to be Inducted by my party @NCPspeaks...
# 10              5  BJP announces 3 more candidates for Gujarat po...
# 12              0  @PadmajaJoshi Gujarat is one of the nicest sta...

# %%
plt.figure(figsize=(20,10))
chart = sns.countplot(data=pro, x="Location")
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
#plt.title("Release Year Wise")
#barPerc(df,"Location",chart)
plt.savefig('loc2.jpg')
plt.show()
# Out:
# C:\Users\kushj\AppData\Local\Temp\ipykernel_7188\3437258011.py:11: UserWarning: Glyph 2349 (\N{DEVANAGARI LETTER BHA}) missing from current font.
#   plt.savefig('loc2.jpg')
# C:\Users\kushj\AppData\Local\Temp\ipykernel_7188\3437258011.py:11: UserWarning: Matplotlib currently does not support Devanagari natively.
#   plt.savefig('loc2.jpg')
# C:\Users\kushj\AppData\Local\Temp\ipykernel_7188\3437258011.py:11: UserWarning: Glyph 2366 (\N{DEVANAGARI VOWEL SIGN AA}) missing from current font.
#   plt.savefig('loc2.jpg')
# C:\Users\kushj\AppData\Local\Temp\ipykernel_7188\3437258011.py:11: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from current font.
#   plt.savefig('loc2.jpg')
# C:\Users\kushj\AppData\Local\Temp\ipykernel_7188\3437258011.py:11: UserWarning: Glyph 2340 (\N{DEVANAGARI LETTER TA}) missing from current font.
#   plt.savefig('loc2.jpg')
# ...

# %%
plt.figure(figsize=(100,100))
chart = sns.countplot(data=df, x="Location",order=df['Location'].value_counts().index)
chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
#plt.title("Release Year Wise")
plt.savefig('loc1.jpg')
plt.show()
# Out:
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_5492\3912391850.py:5: UserWarning: Glyph 128099 (\N{FOOTPRINTS}) missing from current font.
#   plt.savefig('loc1.jpg')
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_5492\3912391850.py:5: UserWarning: Glyph 127758 (\N{EARTH GLOBE AMERICAS}) missing from current font.
#   plt.savefig('loc1.jpg')
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_5492\3912391850.py:5: UserWarning: Glyph 128690 (\N{BICYCLE}) missing from current font.
#   plt.savefig('loc1.jpg')
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_5492\3912391850.py:5: UserWarning: Glyph 128664 (\N{ONCOMING AUTOMOBILE}) missing from current font.
#   plt.savefig('loc1.jpg')
# C:\Users\Harshit\AppData\Local\Temp\ipykernel_5492\3912391850.py:5: UserWarning: Glyph 128676 (\N{SPEEDBOAT}) missing from current font.
#   plt.savefig('loc1.jpg')
# ...

# %%
pro
# Out:
#               Location  Followinf Count  Followers Count  Total Tweets  \
# 1                  NaN              448               90          2838
# 2                India             1784            10797         89266
# 3                  NaN             5081            19230        440481
# 4                  NaN              322              289         12116
# 7       Union of India             4783             7282        238746
# ...                ...              ...              ...           ...
# 2118  Bengaluru, India               82              244         14467
# 2119         Bangalore              920              358          7769
# 2120               NaN             3613             2443        138018
# 2121               NaN                6                5           800
# 2122    Gujarat, India               63           887426        416251
#
#       Retweet Count                                         Tweet Text
# ...

# %%
df["Location"].isnull().sum()
# Out:
# 686

# %%
#pip install geopy

# %%
#pip install folium

# %%
df1=df
df1.dropna()
df1.head()
# Out:
#          Location  Followinf Count  Followers Count  Total Tweets  \
# 0   🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵              2019            13689        347524
# 1             NaN              448               90          2838
# 2           India             1784            10797         89266
# 3             NaN             5081            19230        440481
# 4             NaN              322              289         12116
#
#    Retweet Count                                         Tweet Text
# 0             72  An emotional appeal from a Gujarati Mata Ji to...
# 1             84  Can't stop laughing!! 🤣😂😂😂\r\n\r\nGujarat will...
# 2             66  Nomination rally of Congress candidate Gulab S...
# 3             34  Breaking news: Kanchan Jariwala, the #AAP's Su...
# 4              5  @AAPHaryana Meanwhile AAP in Punjab 👇👇 #Justic...

# %%
df1 = df

# %%
df1.head()
# Out:
#          Location  Followinf Count  Followers Count  Total Tweets  \
# 0   🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵              2019            13689        347524
# 1             NaN              448               90          2838
# 2           India             1784            10797         89266
# 3             NaN             5081            19230        440481
# 4             NaN              322              289         12116
#
#    Retweet Count                                         Tweet Text
# 0             72  an emotional appeal from a gujarati mata ji to...
# 1             84  can't stop laughing!! 🤣😂😂😂\r\n\r\ngujarat will...
# 2             66  nomination rally of congress candidate gulab s...
# 3             34  breaking news: kanchan jariwala, the #aap's su...
# 4              5  @aapharyana meanwhile aap in punjab 👇👇 #justic...

# %%
from geopy.geocoders import ArcGIS
import folium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7188\1404761400.py in <module>
# ----> 1 from geopy.geocoders import ArcGIS
#       2 import folium
#
# ModuleNotFoundError: No module named 'geopy'

# %%
for i in pro['Location']:
    nom=ArcGIS()
    nom.geocode(i)
    if i=="":
        continue
    print(i)
    map=folium.Map(location=[s.latitude,s.longitude],zoom_start=15)
    map.add_child(folium.Marker(location=[s.latitude,s.longitude],popup='Tughlakabad',icon=folium.Icon(color='green')))
    map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7188\4223015639.py in <module>
#       1 for i in pro['Location']:
# ----> 2     nom=ArcGIS()
#       3     nom.geocode(i)
#       4     if i=="":
#       5         continue
#
# NameError: name 'ArcGIS' is not defined

# %%
df1['Tweet Text']=df1['Tweet Text'].str.lower()
df1.to_csv('data.csv')
df1
# Out:
#               Location  Followinf Count  Followers Count  Total Tweets  \
# 0        🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵              2019            13689        347524
# 1                  NaN              448               90          2838
# 2                India             1784            10797         89266
# 3                  NaN             5081            19230        440481
# 4                  NaN              322              289         12116
# ...                ...              ...              ...           ...
# 2118  Bengaluru, India               82              244         14467
# 2119         Bangalore              920              358          7769
# 2120               NaN             3613             2443        138018
# 2121               NaN                6                5           800
# 2122    Gujarat, India               63           887426        416251
#
#       Retweet Count                                         Tweet Text
# ...

# %%
import re

# %%
df1 = pd.read_csv("Tweets1.csv")
df1=df1.drop(['Tweet Scraped','Username','Hashtags Used','Description'],axis=1)
df1.dropna()
df1['Tweet Text']=df1['Tweet Text'].str.lower()

# %%
df = pd.read_csv("data.csv")

# %%
 # removal of 
def clean(text):
    text= re.sub(r'https?://[^ ]+', '', text)  # links
#     text= re.sub(r'@[^ ]+', '', text)           # username
#     text=re.sub(r'#', '', text)                    # hashtag
    #text=emoji.demojize(text)                # emoji to text
    text = re.sub("@[A-Za-z0-9_]+","", text)
    text  = re.sub(r'#','', text)
    text=re.sub(r'[^A-Za-z ]', '', text)
    return text
def clean2(text):
    text= re.sub(r'https?://[^ ]+', '', text)  # links
    text = re.sub(r'@','', text)
    text  = re.sub(r'#','', text)
    text=re.sub(r'[^A-Za-z ]', '', text)
    return text

# %%
df['Tweet Text']=df['Tweet Text'].apply(lambda x: clean(x))
df1['Tweet Text']=df1['Tweet Text'].apply(lambda x: clean2(x))

# %%
df
# Out:
#       Unnamed: 0          Location  Followinf Count  Followers Count  \
# 0              0     🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵              2019            13689
# 1              1               NaN              448               90
# 2              2             India             1784            10797
# 3              3               NaN             5081            19230
# 4              4               NaN              322              289
# ...          ...               ...              ...              ...
# 2118        2118  Bengaluru, India               82              244
# 2119        2119         Bangalore              920              358
# 2120        2120               NaN             3613             2443
# 2121        2121               NaN                6                5
# 2122        2122    Gujarat, India               63           887426
#
#       Total Tweets  Retweet Count  \
# 0           347524             72
# 1             2838             84
# ...

# %%
df1
# Out:
#               Location  Followinf Count  Followers Count  Total Tweets  \
# 0        🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵              2019            13689        347524
# 1                  NaN              448               90          2838
# 2                India             1784            10797         89266
# 3                  NaN             5081            19230        440481
# 4                  NaN              322              289         12116
# ...                ...              ...              ...           ...
# 2118  Bengaluru, India               82              244         14467
# 2119         Bangalore              920              358          7769
# 2120               NaN             3613             2443        138018
# 2121               NaN                6                5           800
# 2122    Gujarat, India               63           887426        416251
#
#       Retweet Count                                         Tweet Text
# ...

# %%
# !python -m spacy download en_core_web_sm

# %%
# !pip install spacy
import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_sm")

# %%
def ner1(text, l = list()):
    doc=nlp(text)
    for word in doc.ents:
        l.append(word.text)
       # l.append(word.label_)

# %%
l = []
l1 = []
for i in df1['Tweet Text']:
    ner1(i,l)
for i in df['Tweet Text']:
    ner1(i,l1)

# %%
len(l)
# Out:
# 3061

# %%
len(l1)
# Out:
# 2633

# %%
l2 = [i if i in l1 else None for i in l]

# %%
len(l2)
# Out:
# 3061

# %%
words_comp = pd.DataFrame({'l':l,'l2':l2})

# %%
words_comp.to_csv('words_comp01.csv')

# %%
tokens_to_consider = list(set(l) - set(l1))

# %%
tokens_to_consider
# Out:
# ['reshmapatel tarishisharma pkakkar kangmalvinder',
#  'drprashantkorat',
#  'supportpmoindia bjpcentralmedia',
#  'nikkhhiljethwa darshannpopat',
#  'shaileshvegad',
#  'gulabmatiala aamaadmiparty',
#  'gujarat padmajajoshi',
#  'iycgujarat',
#  'ritugurjar',
#  'snehal joshi',
#  'anuragdhanda',
#  'officejmscindia jmscindia',
#  'vijayeagleeye',
#  'jamnagar congratulations imjadeja',
#  'rssorg bjpindia',
#  'vtvgujarati bjp',
#  'aamaadmiparty gopalitalia',
#  'inc mlas',
#  'gandhinagar south',
#  'rrbntpcresultdopmoindia railminindia ashwinivaishnaw narendramodirrbkolkata rrbrecruitment',
#  'aravlli modasa',
#  'ji v rahulgandhi',
#  'daarubaazmehta thenewdawnforaa gulabmatiala',
#  'gandhiiyc',
#  'imjadeja gopalitalia',
#  'jagannath puri',
#  'mumbaifirst justicendtruth ksihfoundation',
#  'vikrantgupta sushantmehraat',
#  'ji v',
#  'aloksharmaaicc jiexposing',
#  'patelnirali reshmapatel pkakkar rajubhaikarpad',
#  'kamalkantmishra sudhanidhib',
# ...

# %%
len(tokens_to_consider)
# Out:
# 277

# %%
def CountFrequency(my_list,freq = dict()):
    c=0;
    # Creating an empty dictionary
#     freq = {}
    for item in my_list:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1
    return freq
#     for key, value in freq.items():
#         if value >3:
#             print (key, value)
#         c+=1
#     print(c)

# %%
fw = CountFrequency(tokens_to_consider)
fw
# Out:
# {'reshmapatel tarishisharma pkakkar kangmalvinder': 1,
#  'drprashantkorat': 1,
#  'supportpmoindia bjpcentralmedia': 1,
#  'nikkhhiljethwa darshannpopat': 1,
#  'shaileshvegad': 1,
#  'gulabmatiala aamaadmiparty': 1,
#  'gujarat padmajajoshi': 1,
#  'iycgujarat': 1,
#  'ritugurjar': 1,
#  'snehal joshi': 1,
#  'anuragdhanda': 1,
#  'officejmscindia jmscindia': 1,
#  'vijayeagleeye': 1,
#  'jamnagar congratulations imjadeja': 1,
#  'rssorg bjpindia': 1,
#  'vtvgujarati bjp': 1,
#  'aamaadmiparty gopalitalia': 1,
#  'inc mlas': 1,
#  'gandhinagar south': 1,
#  'rrbntpcresultdopmoindia railminindia ashwinivaishnaw narendramodirrbkolkata rrbrecruitment': 1,
#  'aravlli modasa': 1,
#  'ji v rahulgandhi': 1,
#  'daarubaazmehta thenewdawnforaa gulabmatiala': 1,
#  'gandhiiyc': 1,
#  'imjadeja gopalitalia': 1,
#  'jagannath puri': 1,
#  'mumbaifirst justicendtruth ksihfoundation': 1,
#  'vikrantgupta sushantmehraat': 1,
#  'ji v': 1,
#  'aloksharmaaicc jiexposing': 1,
# ...

# %%
def ner(text,a=dict(),ct_wrds = dict()):
    cnt=int(0)
    doc=nlp(text)
    for token in doc:
        if cnt == 0:
            cnt = 1
        if (token.text not in ct_wrds):
            ct_wrds[token.text] = token.pos_
    for word in doc.ents:
        item = word.text
        if (item in a):
            a[item] += 1
        else:
            a[item] = 1
       # print(word.text,word.label_,str(spacy.explain(word.label_)))
       #print(a)
    return (a,ct_wrds)

# %%
a=dict()
ct_wrds = dict()
for i in df['Tweet Text']:
    ner(i,a,ct_wrds)

# %%
for i in tokens_to_consider:
    ner(i,a,ct_wrds)

# %%
ct_wrds['jadeja']
# Out:
# 'PROPN'

# %%
ab=dict(sorted(a.items(),key = lambda x:x[1],reverse=True))
ab
# Out:
# {'gujarat': 553,
#  'congress': 214,
#  'india': 97,
#  'today': 47,
#  'ravindra jadeja': 42,
#  'aapgujarat': 38,
#  'indian': 34,
#  'gujarat assembly': 31,
#  'shreyasiyer teamindia bcci': 28,
#  'first': 27,
#  'december': 25,
#  'klrahul': 21,
#  'one': 20,
#  'november': 19,
#  'three': 19,
#  'pm narendra': 19,
#  'bhupendra patel': 19,
#  'kejriwal': 16,
#  'indvsban': 16,
#  'ji': 15,
#  'bcci': 15,
#  'rivaba jadeja': 14,
#  'jamnagar north': 14,
#  'kanchan jariwala': 14,
#  'gandhi': 14,
#  'years': 13,
#  'muslims': 13,
#  'kumar': 12,
#  'shahbaz ahmed': 12,
#  'delhi': 11,
#  'wednesday': 11,
#  'indvban': 11,
#  'two': 10,
#  'second': 10,
#  'saturday': 10,
#  'ec': 10,
#  'vadodaranews news': 10,
#  'muslim': 9,
#  'bhavnagar': 9,
#  'cm bhupendra patel': 9,
#  'tomorrow': 8,
#  'jamnagar': 8,
#  'narendra': 8,
#  'the last  years': 8,
#  'bhandari': 8,
#  'ravindra jadejas': 7,
#  'east kanchan jariwala': 7,
#  'ani': 7,
#  'himachal pradesh assembly': 7,
# ...

# %%
s = list(ab.keys())
f = list(ab.values())

# %%
typ = [ct_wrds[i] if i in ct_wrds else( ct_wrds[i.split()[0]] if i.split()[0] in ct_wrds else None ) for i in s]

# %%
df3= pd.DataFrame({'NER':s,'freq':f,'type':typ},columns =['NER','freq','type'])
df3.to_csv('NER_temp_01.csv')
df3
# Out:
#                                                     NER  freq   type
# 0                                               gujarat   553   NOUN
# 1                                              congress   214  PROPN
# 2                                                 india    97  PROPN
# 3                                                 today    47   NOUN
# 4                                       ravindra jadeja    42  PROPN
# ...                                                 ...   ...    ...
# 1030                                    delhiaapgujarat     1  PROPN
# 1031                        jerzeyredhead sekoufranklin     1  PROPN
# 1032                               brijdoshi bjpgujarat     1  PROPN
# 1033  garrywalia gujaratassemblypolls projectionbjp ...     1  PROPN
# 1034                                     bjpgujarat pls     1  PROPN
#
# [1035 rows x 3 columns]

# %%
df4 = df3.loc[(df3['type'] == 'NOUN') | (df3['type'] == 'PROPN')]

# %%
df4.to_csv("NER_noun_01.csv")

# %%
ct_wrds = dict()
for token in df3['NER']:
            token = nlp(token)
#             print(token)/
            for t in token:
                print(t)
                print(t.pos_)
# Out:
# gujarat
# NOUN
# congress
# PROPN
# india
# PROPN
# today
# NOUN
# ravindra
# PROPN
# jadeja
# ADV
# aapgujarat
# PROPN
# indian
# ADJ
# gujarat
# PROPN
# assembly
# NOUN
# shreyasiyer
# PROPN
# teamindia
# PROPN
# bcci
# PROPN
# first
# ADV
# december
# PROPN
# klrahul
# PROPN
# one
# NUM
# november
# PROPN
# three
# NUM
# pm
# PROPN
# narendra
# X
# bhupendra
# NOUN
# patel
# NOUN
# kejriwal
# PROPN
# indvsban
# ADJ
# ji
# PROPN
# bcci
# PROPN
# rivaba
# PROPN
# jadeja
# NOUN
# jamnagar
# PROPN
# north
# NOUN
# kanchan
# PROPN
# jariwala
# PROPN
# gandhi
# PROPN
# years
# NOUN
# muslims
# NOUN
# kumar
# PROPN
# shahbaz
# PROPN
# ahmed
# VERB
# delhi
# PROPN
# wednesday
# PROPN
# indvban
# NOUN
# two
# NUM
# second
# ADJ
# saturday
# PROPN
# ec
# PROPN
# vadodaranews
# VERB
# news
# NOUN
# muslim
# PROPN
# bhavnagar
# PROPN
# cm
# PROPN
# bhupendra
# NOUN
# patel
# PROPN
# tomorrow
# NOUN
# jamnagar
# NOUN
# narendra
# PROPN
# the
# DET
# last
# ADJ
#
# SPACE
# years
# NOUN
# ...

# %%
# s = list(a)
# df3= pd.DataFrame(s,columns =['NER'])
# df3.to_csv('NER_1.csv')
# df3

# %%
df2=df
df2
# Out:
#       Unnamed: 0          Location  Followinf Count  Followers Count  \
# 0              0     🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵              2019            13689
# 1              1               NaN              448               90
# 2              2             India             1784            10797
# 3              3               NaN             5081            19230
# 4              4               NaN              322              289
# ...          ...               ...              ...              ...
# 2118        2118  Bengaluru, India               82              244
# 2119        2119         Bangalore              920              358
# 2120        2120               NaN             3613             2443
# 2121        2121               NaN                6                5
# 2122        2122    Gujarat, India               63           887426
#
#       Total Tweets  Retweet Count  \
# 0           347524             72
# 1             2838             84
# ...

# %%
import nltk
# nltk.download('wordnet')
# nltk.download('omw-1.4')

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
def stemSentence(sentence):
    token_words=word_tokenize(sentence)
    token_words
    stem_sentence=[]
    for word in token_words:
        stem_sentence.append(porter.stem(word))
        stem_sentence.append(" ")
    return "".join(stem_sentence)
df2['Tweet Text'] = df2['Tweet Text'].apply(lambda x : stemSentence(x))
df2
# Out:
#       Followinf Count  Followers Count  Total Tweets  Retweet Count  \
# 0                2019            13689        347524             72
# 1                 448               90          2838             84
# 2                1784            10797         89266             66
# 3                5081            19230        440481             34
# 4                 322              289         12116              5
# ...               ...              ...           ...            ...
# 2118               82              244         14467              0
# 2119              920              358          7769              1
# 2120             3613             2443        138018              5
# 2121                6                5           800             43
# 2122               63           887426        416251              0
#
#                                              Tweet Text
# 0         an emot appeal from a gujarati mata ji to ji
# ...

# %%
b=set()
def ner1(text):
    doc=nlp(text)
    for word in doc.ents:
        b.add(word.text)
for i in df2['Tweet Text']:
    ner1(i)

# %%
# s = list(b)
# df3= pd.DataFrame(s,columns =['NER'])
# df3.to_csv('NER_2.csv')
# df3
# Out:
#                 NER
# 0             bridg
# 1           cm hold
# 2              rs k
# 3           himanta
# 4       jiyesterday
# ..              ...
# 794       karnataka
# 795  jagannath puri
# 796          ab nhi
# 797            tens
# 798        tens now
#
# [799 rows x 1 columns]

# %%
l=[]
def ner1(text):
    doc=nlp(text)
    for word in doc.ents:
        l.append(word.text)
        l.append(word.label_)
for i in df1['Tweet Text']:
    ner1(i)

# %%
def CountFrequency(my_list):
    c=0;
    # Creating an empty dictionary
    freq = {}
    for item in my_list:
        if (item in freq):
            freq[item] += 1
        else:
            freq[item] = 1
 
    for key, value in freq.items():
        if value >3:
            print (key, value)
        c+=1
    print(c)

# %%
CountFrequency(l)
# Out:
# gujarati 5
# GPE 657
# gujarat 388
# delhi 8
# PERSON 663
# congress 141
# ORG 526
# meanwhil 6
# muslim 16
# NORP 128
# three 18
# CARDINAL 84
# indian 30
# india 93
# kejriw 13
# DATE 209
# kumar 13
# rivaba jadeja 14
# jamnagar north 13
# ncp 14
# chang 6
# bridg 4
# two 10
# one 22
# upcom 20
# saurashtra 5
# pm narendra 19
# gujarat assembl 16
# tomorrow 10
# second 10
# ORDINAL 44
# ki 4
# novemb 9
# FAC 15
# everi 10
# bhupendra patel 20
# east kanchan jariwala 5
# hai 5
# reshma patel 4
# wednesday 11
# cm bhupendra patel 9
# union home minist amit 5
# rt amit shah 5
# kanchan jariwala 12
# today 72
# year 11
# first 27
# surat east 4
# LOC 21
# zero 6
# bhai 6
# ravindra jadeja 31
# jamnagar 6
# veri 20
# TIME 11
# ec 10
# gandhi 15
# ji 11
# morbi bridg 4
# surat 4
# ani 10
# PRODUCT 7
# madhu 4
# st decemb 6
# third 4
# famou 4
# next month 8
# congress nd 4
# saturday 10
# cm jairam thakur 19
# sadhana thakur 8
# six 5
# hamirpur 5
# five 5
# overtak delhi 6
# welcom 6
# ...

# %%
# Out:
# 0
