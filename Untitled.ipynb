# %%
#pip install emoji

# %%
import pandas as pd

# %%
df=pd.read_csv("Tweets1.csv")

# %%
df
# Out:
#       Tweet Scraped         Username  \
# 0                 1   hatefreeworldX
# 1                 2  sashastrakranti
# 2                 3     GuptaPragnya
# 3                 5     CongressFans
# 4                 7  Har_preet_Kaur_
# ...             ...              ...
# 2118             41      iamShamanth
# 2119             42       anoop_xing
# 2120            203  Harjind35133736
# 2121            207   kurtapajama101
# 2122              1      tv9gujarati
#
#                                             Description          Location  \
# 0     Vasudhaiva Kutumbakam-World is family | Bharat...     🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵
# 1                                                सनातनी               NaN
# 2     Constitution of India above all. My opinions a...             India
# 3                                                   NaN               NaN
# 4     Assistant Professor of English | UGC NET Quali...               NaN
# ...

# %%
df1=df.drop(['Tweet Scraped','Username','Location','Hashtags Used','Description'],axis=1)

# %%
df1
# Out:
#       Followinf Count  Followers Count  Total Tweets  Retweet Count  \
# 0                2019            13689        347524             72
# 1                 448               90          2838             84
# 2                1784            10797         89266             66
# 3                5081            19230        440481             34
# 4                 322              289         12116              5
# ...               ...              ...           ...            ...
# 2118               82              244         14467              0
# 2119              920              358          7769              1
# 2120             3613             2443        138018              5
# 2121                6                5           800             43
# 2122               63           887426        416251              0
#
#                                              Tweet Text
# 0     An emotional appeal from a Gujarati Mata Ji to...
# ...

# %%
df1['Tweet Text']=df1['Tweet Text'].str.lower()
df1.to_csv('data.csv')
df1
# Out:
#       Followinf Count  Followers Count  Total Tweets  Retweet Count  \
# 0                2019            13689        347524             72
# 1                 448               90          2838             84
# 2                1784            10797         89266             66
# 3                5081            19230        440481             34
# 4                 322              289         12116              5
# ...               ...              ...           ...            ...
# 2118               82              244         14467              0
# 2119              920              358          7769              1
# 2120             3613             2443        138018              5
# 2121                6                5           800             43
# 2122               63           887426        416251              0
#
#                                              Tweet Text
# 0     an emotional appeal from a gujarati mata ji to...
# ...

# %%
import re
import emoji

# %%
 # removal of 
def clean(text):
    text= re.sub(r'https?://[^ ]+', '', text)  # links
    text= re.sub(r'@[^ ]+', '', text)           # username
    text=re.sub(r'#', '', text)                    # hashtag
    #text=emoji.demojize(text)                # emoji to text
    text=re.sub(r'[^A-Za-z ]', '', text)      
    return text
df1['Tweet Text']=df1['Tweet Text'].apply(lambda x: clean(x))

# %%
df1
# Out:
#       Followinf Count  Followers Count  Total Tweets  Retweet Count  \
# 0                2019            13689        347524             72
# 1                 448               90          2838             84
# 2                1784            10797         89266             66
# 3                5081            19230        440481             34
# 4                 322              289         12116              5
# ...               ...              ...           ...            ...
# 2118               82              244         14467              0
# 2119              920              358          7769              1
# 2120             3613             2443        138018              5
# 2121                6                5           800             43
# 2122               63           887426        416251              0
#
#                                              Tweet Text
# 0     an emotional appeal from a gujarati mata ji to...
# ...

# %%
#pip install spacy
import spacy
from spacy import displacy
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(u'Microsoft is trying to buy France based startup at $7 Million')
for token in doc:
  print(token.text)
# Out:
# Microsoft
# is
# trying
# to
# buy
# France
# based
# startup
# at
# $
# 7
# Million

# %%
for token in doc:
    print(token, token.pos_)
# Out:
# Microsoft PROPN
# is AUX
# trying VERB
# to PART
# buy VERB
# France PROPN
# based VERB
# startup NOUN
# at ADP
# $ SYM
# 7 NUM
# Million NUM

# %%
for word in doc.ents:
    print(word.text,word.label_,str(spacy.explain(word.label_)))
# Out:
# Microsoft ORG Companies, agencies, institutions, etc.
# France GPE Countries, cities, states
# $7 Million MONEY Monetary values, including unit

# %%
displacy.render(doc,style="ent",jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Microsoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is trying to buy
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  based startup at
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $7 Million
# ...

# %%
" ".join([token.lemma_ for token in doc])
# Out:
# 'Microsoft be try to buy France base startup at $ 7 million'

# %%
# def ner(text):
#     doc=nlp(text)
#     for word in doc.ents:
#         print(word.text,word.label_,str(spacy.explain(word.label_)))
        
# for i in df1['Tweet Text']:
#     ner(i)

# %%
a=set()
def ner(text):
    doc=nlp(text)
    for word in doc.ents:
        a.add(word.text)
       # print(word.text,word.label_,str(spacy.explain(word.label_)))
       #print(a)
        
for i in df1['Tweet Text']:
    ner(i)

# %%
s = list(a)
df3= pd.DataFrame(s,columns =['NER'])
df3.to_csv('NER.csv')
df3
# Out:
#                            NER
# 0         imandar rajniti mate
# 1                     only one
# 2                    gpcc prez
# 3                     narendra
# 4                     greenery
# ..                         ...
# 807         cm  bhupendrapatel
# 808         kanchan jariwala
# 809                    sidhpur
# 810                   vijaypur
# 811  rohitsharma shikhardhawan
#
# [812 rows x 1 columns]

# %%
df2=df1
df2
# Out:
#       Followinf Count  Followers Count  Total Tweets  Retweet Count  \
# 0                2019            13689        347524             72
# 1                 448               90          2838             84
# 2                1784            10797         89266             66
# 3                5081            19230        440481             34
# 4                 322              289         12116              5
# ...               ...              ...           ...            ...
# 2118               82              244         14467              0
# 2119              920              358          7769              1
# 2120             3613             2443        138018              5
# 2121                6                5           800             43
# 2122               63           887426        416251              0
#
#                                              Tweet Text
# 0     an emotional appeal from a gujarati mata ji to...
# ...

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Harshit\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Harshit\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
def stemSentence(sentence):
    token_words=word_tokenize(sentence)
    token_words
    stem_sentence=[]
    for word in token_words:
        stem_sentence.append(porter.stem(word))
        stem_sentence.append(" ")
    return "".join(stem_sentence)
df2['Tweet Text'] = df2['Tweet Text'].apply(lambda x : stemSentence(x))
df2
# Out:
#       Followinf Count  Followers Count  Total Tweets  Retweet Count  \
# 0                2019            13689        347524             72
# 1                 448               90          2838             84
# 2                1784            10797         89266             66
# 3                5081            19230        440481             34
# 4                 322              289         12116              5
# ...               ...              ...           ...            ...
# 2118               82              244         14467              0
# 2119              920              358          7769              1
# 2120             3613             2443        138018              5
# 2121                6                5           800             43
# 2122               63           887426        416251              0
#
#                                              Tweet Text
# 0     an emot appeal from a gujarati mata ji to ji g...
# ...

# %%
b=set()
def ner1(text):
    doc=nlp(text)
    for word in doc.ents:
        b.add(word.text)
for i in df2['Tweet Text']:
    ner1(i)

# %%
s = list(b)
df3= pd.DataFrame(s,columns =['NER'])
df3.to_csv('NER4.csv')
df3
# Out:
#                                NER
# 0                  jamnagar pictur
# 1                      everi dayit
# 2             imandar rajniti mate
# 3                   jp nadda union
# 4                inspiringhonbl pm
# ...                            ...
# 1031               jamnagar market
# 1032                 multipl ralli
# 1033  decemberallround shahbaz ahm
# 1034                      vijaypur
# 1035     rohitsharma shikhardhawan
#
# [1036 rows x 1 columns]
