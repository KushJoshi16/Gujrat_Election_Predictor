# %%
import pandas as pd
import os
import glob

# %%
#list all csv files only
os.chdir(r'C:\Users\Harshit\Gujarat_Elec\Data')
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['scraped_data.csv',
#  'scraped_data_01.csv',
#  'scraped_data_102.csv',
#  'scraped_data_103.csv',
#  'scraped_data_104.csv',
#  'scraped_data_105.csv',
#  'scraped_data_106.csv',
#  'scraped_data_107.csv',
#  'scraped_data_mod.csv']

# %%
df = pd.concat([pd.read_csv(f) for f in csv_files ], ignore_index=True)
df
# Out:
#        Tweet Scraped         Username  \
# 0                NaN              NaN
# 1                1.0   hatefreeworldX
# 2                NaN              NaN
# 3                2.0  sashastrakranti
# 4                NaN              NaN
# ...              ...              ...
# 17620           52.0              NaN
# 17621            NaN              NaN
# 17622           53.0              NaN
# 17623            NaN              NaN
# 17624            1.0              NaN
#
#                                              Description        Location  \
# 0                                                    NaN             NaN
# 1      Vasudhaiva Kutumbakam-World is family | Bharat...   🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵
# 2                                                    NaN             NaN
# 3                                                 सनातनी             NaN
# 4                                                    NaN             NaN
# ...                                                  ...             ...
# 17620                                                NaN             NaN
# 17621                                                NaN             NaN
# 17622                                                NaN             NaN
# 17623                                                NaN             NaN
# 17624                                                NaN             NaN
#
#        Followinf Count  Followers Count  Total Tweets  Retweet Count  \
# 0                  NaN              NaN           NaN            NaN
# 1               2019.0          13689.0      347524.0           72.0
# 2                  NaN              NaN           NaN            NaN
# 3                448.0             90.0        2838.0           84.0
# 4                  NaN              NaN           NaN            NaN
# ...                ...              ...           ...            ...
# 17620              NaN              NaN           NaN            NaN
# 17621              NaN              NaN           NaN            NaN
# 17622              NaN              NaN           NaN            NaN
# 17623              NaN              NaN           NaN            NaN
# 17624              NaN              NaN           NaN            NaN
#
#                                               Tweet Text  \
# 0                                                    NaN
# 1      An emotional appeal from a Gujarati Mata Ji to...
# 2                                                    NaN
# 3      Can't stop laughing!! 🤣😂😂😂\r\n\r\nGujarat will...
# 4                                                    NaN
# ...                                                  ...
# 17620                                                NaN
# 17621                                                NaN
# 17622                                                NaN
# 17623                                                NaN
# 17624                                                NaN
#
#                  Hashtags Used
# 0                          NaN
# 1      ['GujaratElection2022']
# 2                          NaN
# 3                           []
# 4                          NaN
# ...                        ...
# 17620                      NaN
# 17621                      NaN
# 17622                      NaN
# 17623                      NaN
# 17624                      NaN
#
# [17625 rows x 10 columns]

# %%
DF = df.drop_duplicates(subset="Tweet Text",keep='first')

# %%
DF
# Out:
#        Tweet Scraped         Username  \
# 0                NaN              NaN
# 1                1.0   hatefreeworldX
# 3                2.0  sashastrakranti
# 5                3.0     GuptaPragnya
# 9                5.0     CongressFans
# ...              ...              ...
# 12959           41.0      iamShamanth
# 12960           42.0       anoop_xing
# 13121          203.0  Harjind35133736
# 13125          207.0   kurtapajama101
# 13316            1.0      tv9gujarati
#
#                                              Description          Location  \
# 0                                                    NaN               NaN
# 1      Vasudhaiva Kutumbakam-World is family | Bharat...     🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵
# 3                                                 सनातनी               NaN
# 5      Constitution of India above all. My opinions a...             India
# 9                                                    NaN               NaN
# ...                                                  ...               ...
# 12959                                    Be Good Do Good  Bengaluru, India
# 12960  आजादी की दूसरी लड़ाई का दर्पण, देश की भ्रष्ट व्...         Bangalore
# 13121                                        केजरीवाल सर               NaN
# 13125                                                NaN               NaN
# 13316  NO.1 GUJARATI NEWS CHANNEL. Follow us for brea...    Gujarat, India
#
#        Followinf Count  Followers Count  Total Tweets  Retweet Count  \
# 0                  NaN              NaN           NaN            NaN
# 1               2019.0          13689.0      347524.0           72.0
# 3                448.0             90.0        2838.0           84.0
# 5               1784.0          10797.0       89266.0           66.0
# 9               5081.0          19230.0      440481.0           34.0
# ...                ...              ...           ...            ...
# 12959             82.0            244.0       14467.0            0.0
# 12960            920.0            358.0        7769.0            1.0
# 13121           3613.0           2443.0      138018.0            5.0
# 13125              6.0              5.0         800.0           43.0
# 13316             63.0         887426.0      416251.0            0.0
#
#                                               Tweet Text  \
# 0                                                    NaN
# 1      An emotional appeal from a Gujarati Mata Ji to...
# 3      Can't stop laughing!! 🤣😂😂😂\r\n\r\nGujarat will...
# 5      Nomination rally of Congress candidate Gulab S...
# 9      Breaking news: Kanchan Jariwala, the #AAP's Su...
# ...                                                  ...
# 12959  Getting Goosebumps seeing this 🥹❤️\r\nKeep spr...
# 12960  Today's public meeting in Surat. \r\n\r\n #Guj...
# 13121  Why is BJP sleepless?\r\nThe behind door 2 doo...
# 13125  Ye kya bol gaye Uncle ..🧐🤨\r\n\r\n#GujaratWith...
# 13316  Gujarat CM #BhupendraPatel criticizes the cont...
#
#                                            Hashtags Used
# 0                                                    NaN
# 1                                ['GujaratElection2022']
# 3                                                     []
# 5                                                     []
# 9                                                ['AAP']
# ...                                                  ...
# 12959  ['Surat', 'Gujarat', 'GujaratElections2022', '...
# 12960         ['GujaratElections2022', 'GujaratWithAAP']
# 13121                                            ['AAP']
# 13125  ['GujaratWithKejriwal', 'GujaratWithAAP', 'EkM...
# 13316  ['BhupendraPatel', 'Gujarat', 'GujaratElection...
#
# [2124 rows x 10 columns]

# %%
DF.to_csv('MergeTweets.csv')
DF
# Out:
#        Tweet Scraped         Username  \
# 0                NaN              NaN
# 1                1.0   hatefreeworldX
# 3                2.0  sashastrakranti
# 5                3.0     GuptaPragnya
# 9                5.0     CongressFans
# ...              ...              ...
# 12959           41.0      iamShamanth
# 12960           42.0       anoop_xing
# 13121          203.0  Harjind35133736
# 13125          207.0   kurtapajama101
# 13316            1.0      tv9gujarati
#
#                                              Description          Location  \
# 0                                                    NaN               NaN
# 1      Vasudhaiva Kutumbakam-World is family | Bharat...     🇮🇳🇧🇩🇵🇰🇱🇰🇧🇹🇳🇵
# 3                                                 सनातनी               NaN
# 5      Constitution of India above all. My opinions a...             India
# 9                                                    NaN               NaN
# ...                                                  ...               ...
# 12959                                    Be Good Do Good  Bengaluru, India
# 12960  आजादी की दूसरी लड़ाई का दर्पण, देश की भ्रष्ट व्...         Bangalore
# 13121                                        केजरीवाल सर               NaN
# 13125                                                NaN               NaN
# 13316  NO.1 GUJARATI NEWS CHANNEL. Follow us for brea...    Gujarat, India
#
#        Followinf Count  Followers Count  Total Tweets  Retweet Count  \
# 0                  NaN              NaN           NaN            NaN
# 1               2019.0          13689.0      347524.0           72.0
# 3                448.0             90.0        2838.0           84.0
# 5               1784.0          10797.0       89266.0           66.0
# 9               5081.0          19230.0      440481.0           34.0
# ...                ...              ...           ...            ...
# 12959             82.0            244.0       14467.0            0.0
# 12960            920.0            358.0        7769.0            1.0
# 13121           3613.0           2443.0      138018.0            5.0
# 13125              6.0              5.0         800.0           43.0
# 13316             63.0         887426.0      416251.0            0.0
#
#                                               Tweet Text  \
# 0                                                    NaN
# 1      An emotional appeal from a Gujarati Mata Ji to...
# 3      Can't stop laughing!! 🤣😂😂😂\r\n\r\nGujarat will...
# 5      Nomination rally of Congress candidate Gulab S...
# 9      Breaking news: Kanchan Jariwala, the #AAP's Su...
# ...                                                  ...
# 12959  Getting Goosebumps seeing this 🥹❤️\r\nKeep spr...
# 12960  Today's public meeting in Surat. \r\n\r\n #Guj...
# 13121  Why is BJP sleepless?\r\nThe behind door 2 doo...
# 13125  Ye kya bol gaye Uncle ..🧐🤨\r\n\r\n#GujaratWith...
# 13316  Gujarat CM #BhupendraPatel criticizes the cont...
#
#                                            Hashtags Used
# 0                                                    NaN
# 1                                ['GujaratElection2022']
# 3                                                     []
# 5                                                     []
# 9                                                ['AAP']
# ...                                                  ...
# 12959  ['Surat', 'Gujarat', 'GujaratElections2022', '...
# 12960         ['GujaratElections2022', 'GujaratWithAAP']
# 13121                                            ['AAP']
# 13125  ['GujaratWithKejriwal', 'GujaratWithAAP', 'EkM...
# 13316  ['BhupendraPatel', 'Gujarat', 'GujaratElection...
#
# [2124 rows x 10 columns]
